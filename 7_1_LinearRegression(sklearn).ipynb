# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/Defense_Cloud/blob/main/7_1_LinearRegression(sklearn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# 예시 데이터 생성 (X는 1차원 배열, y는 종속 변수)
np.random.seed(0)
X = 2 * np.random.rand(100, 1)  # 100개의 샘플 생성
y = 4 + 3 * X + np.random.randn(100, 1)  # y = 4 + 3X + 노이즈 추가

# 훈련/테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 선형 회귀 모델 학습
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred = model.predict(X_test)

# 모델의 성능 평가 (평균 제곱 오차)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'Intercept (절편): {model.intercept_[0]:.2f}')
print(f'Coefficient (기울기): {model.coef_[0][0]:.2f}')

# 데이터 및 회귀 직선 시각화
plt.scatter(X_test, y_test, color="blue", label="Actual Data")
plt.plot(X_test, y_pred, color="red", label="Regression Line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 0.78
# Intercept (절편): 4.18
# Coefficient (기울기): 3.03

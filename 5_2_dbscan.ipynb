# %% [markdown]
# <a href="https://colab.research.google.com/github/juhumkwon/Defense_Cloud/blob/main/5_2_dbscan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [출처] 밀도 기반 군집 분석(DBSCAN) 알고리즘을 이용한 군집 분석 샘플 소스 (Python)|작성자 맑은 하늘

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# 데이터 생성 (초승달 모양 데이터셋)
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)

# DBSCAN 모델 생성 및 학습
dbscan = DBSCAN(eps=0.2, min_samples=5)  # eps: 0.2, min_samples: 5 설정
labels = dbscan.fit_predict(X)

# 시각화
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.title('DBSCAN Clustering')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
